# %%
from prompt_engine.template.eda import BasicDataIngestionOverviewTemplate
from prompt_engine.components.eda import DataIngestionComponent

order = BasicDataIngestionOverviewTemplate.get_components_order()
order
# Out:
# [prompt_engine.registry.eda.data_ingestion.DataIngestionPromptRegistry,
#  prompt_engine.registry.eda.type_handling.TypeHandlingPromptRegistry,
#  prompt_engine.registry.eda.missing_values.MissingValuesPromptRegistry,
#  prompt_engine.registry.eda.univariative_analysis.UnivariativeAnalysisPromptRegistry]

# %%
BasicDataIngestionOverviewTemplate.get_prompt(1,1,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 BasicDataIngestionOverviewTemplate.get_prompt(1,1,1)
#
# TypeError: PromptTemplate.get_prompt() takes from 2 to 3 positional arguments but 4 were given
